# %%
from doc.api import Classifier
from doc.ocr import TesseractOCR

# %%
c = Classifier()

# %%
from PIL import Image

# %%
from glob import glob

# %% [markdown]
# Интерфейс предполагает проверку 1 документа за раз

# %%
fns = glob('data/imgs/1_БТИ/1 *')

# %%
tess = TesseractOCR()

# %%
df = tess.detect(fns[0])

# %%
tess.postprocess(df)
# Out:
#             text  upper_left_y  upper_left_x  upper_right_y  upper_right_x  \
# 0            ГБУ            78           451             78            500
# 1     Московское            78           508             78            646
# 2           бюро            78           778             78            837
# 3    технической            78           845             78            988
# 4      городское            84           655             84            769
# ..           ...           ...           ...            ...            ...
# 276           82          2148           797           2148            827
# 277          266          2148          1349           2148           1387
# 278            ,          2154           427           2154            430
# 279   28.09.2010          2163          1410           2163           1531
# 280           г.          2169          1539           2169           1554
#
#      lower_right_y  lower_right_x  lower_left_y  lower_left_x
# ...

# %%
c.classify_document(fns)

# %%
fns = glob('data/google/4_Разр. на стр-во/1_*')

# %%
fns
# Out:
# ['data/google/4_Разр. на стр-во/1_0_g_ocr.csv',
#  'data/google/4_Разр. на стр-во/1_1_g_ocr.csv']

# %%
c.classify_document(fns)
# Out:
# (1, 512)
# '4_Разр. на стр-во'

# %%
def gather_docs(files):
    import os
    from collections import defaultdict

    fnames = set()
    for f in files:
        fnames.add(os.path.dirname(f) + '/' + os.path.basename(f).split('_')[0])
    docs = defaultdict(list)
    for f in files:
        f_name = os.path.dirname(f) + '/' + os.path.basename(f).split('_')[0]
        docs[f_name].append(f)
    return docs

# %%
tens

# %%
fns = glob('data/google/*/*')

# %%
docs = gather_docs(fns)

# %%
for k,v in docs.items():
    print(k.split('/')[-2])
    print(c.classify_document(v))
# Out:
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# 4_Разр. на стр-во
# ...
